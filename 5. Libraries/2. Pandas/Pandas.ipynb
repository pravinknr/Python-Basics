# %% [markdown]
# ## list -> Series -> Dataframe
#
# ## series - single column DF
# ## DF - More than one column in DF

# %%
# Importing necessary libraries
import pandas as pd # importing pandas = > useful for creating dataframes

# %%
x1 = [1, 2, 3, 4,5] # list format

# %%
x2 = [10, 11, 12,100,11]  # list format

# %%
x3 = list(range(5)) #0,1,2,3,4

# %%
print(x1)
print(x2)
print(x3)
# Out:
# [1, 2, 3, 4, 5]
# [10, 11, 12, 100, 11]
# [0, 1, 2, 3, 4]

# %%
# Creating a data frame using explicits lists
X = pd.DataFrame(columns = ["X1","X2","X3"]) 
X
# Out:
# Empty DataFrame
# Columns: [X1, X2, X3]
# Index: []

# %% [markdown]
# ## X.X1 or X["X1"] - For Column Selection
# * accessing columns using "." (dot) operation - X.X1
# * accessing columns alternative way - X["X1"]

# %%
X["X1"] = pd.Series(x1)  # Converting list format into pandas series format
X.X1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: X1, dtype: int64

# %%
X["X2"] = pd.Series(x2) # Converting list format into pandas series format
X.X2
# Out:
# 0     10
# 1     11
# 2     12
# 3    100
# 4     11
# Name: X2, dtype: int64

# %%
X["X3"] = pd.Series(x3)
X.X3
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: X3, dtype: int64

# %%
X
# Out:
#    X1   X2  X3
# 0   1   10   0
# 1   2   11   1
# 2   3   12   2
# 3   4  100   3
# 4   5   11   4

# %%
X["X1"] = x1 # Converting list format into pandas series format
X["X2"] = x2 # Converting list format into pandas series format
X["X3"] = x3
X
# Out:
#    X1   X2  X3
# 0   1   10   0
# 1   2   11   1
# 2   3   12   2
# 3   4  100   3
# 4   5   11   4

# %%
# Accessing multiple columns : giving column names as input in list format
variable = X[["X1","X2"]]
variable
# Out:
#    X1   X2
# 0   1   10
# 1   2   11
# 2   3   12
# 3   4  100
# 4   5   11

# %%
X[["X1","X2","X3"]]
# Out:
#    X1   X2  X3
# 0   1   10   0
# 1   2   11   1
# 2   3   12   2
# 3   4  100   3
# 4   5   11   4

# %% [markdown]
# ## Accessing elements using ".iloc" and loc : accessing each cell by row and column
#
# * iloc - integer location
# * loc - string location

# %%
# index values
X.iloc[0:3,1]  #0,1,2-rows of 1st column
# Out:
# 0    10
# 1    11
# 2    12
# Name: X2, dtype: int64

# %%
X.iloc[:,[1,2]] #All rows of 2 and 3 columns
# Out:
#     X2  X3
# 0   10   0
# 1   11   1
# 2   12   2
# 3  100   3
# 4   11   4

# %%
X.iloc[:,:] # to get entire data frame
# Out:
#    X1   X2  X3
# 0   1   10   0
# 1   2   11   1
# 2   3   12   2
# 3   4  100   3
# 4   5   11   4

# %%
X.loc[1:3,"X3"]
# Out:
# 1    1
# 2    2
# 3    3
# Name: X3, dtype: int64

# %%
X.loc[1:3,["X1","X3"]]
# Out:
#    X1  X3
# 1   2   1
# 2   3   2
# 3   4   3

# %%
X.loc[[1,3,4],["X1","X2"]]
# Out:
#    X1   X2
# 1   2   11
# 3   4  100
# 4   5   11

# %%
X.loc[0:3,["X1","X2"]] #0,1,2
# Out:
#    X1   X2
# 0   1   10
# 1   2   11
# 2   3   12
# 3   4  100

# %%
# checking the type of variable 
type(X.X1) # pandas series object
# Out:
# pandas.core.series.Series

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(X.X2)
# Out:
# pandas.core.series.Series

# %%
type(X["X2"])
# Out:
# pandas.core.series.Series

# %%
x = pd.DataFrame(columns=["A","B","C"])
x
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
import numpy as np

x["A"] = pd.Series(list(np.random.randint(1,100,50)))   #randint - random integers
x["B"] = pd.Series(list(np.random.choice([0,1],size = 55))) 
x["C"] = 15

# %%
x
# Out:
#      A  B   C
# 0   69  1  15
# 1   50  0  15
# 2   34  0  15
# 3    7  0  15
# 4   23  0  15
# 5   35  1  15
# 6   58  0  15
# 7   29  1  15
# 8   78  1  15
# 9    6  0  15
# 10  69  0  15
# 11  10  1  15
# 12  82  1  15
# 13  25  1  15
# 14  40  1  15
# 15  73  0  15
# 16  45  1  15
# 17  36  0  15
# 18  18  1  15
# 19  48  0  15
# 20  72  1  15
# 21  12  0  15
# 22  78  1  15
# 23  11  0  15
# 24  48  1  15
# 25   1  1  15
# 26   5  1  15
# 27   4  0  15
# 28  22  1  15
# 29  59  0  15
# 30  82  1  15
# 31  65  0  15
# 32  43  0  15
# 33  82  1  15
# 34  30  0  15
# 35  39  1  15
# 36   1  0  15
# 37  26  1  15
# 38  33  1  15
# 39  84  1  15
# 40  45  1  15
# 41   7  1  15
# 42  87  1  15
# 43  96  0  15
# 44  42  0  15
# 45  22  1  15
# 46  85  1  15
# 47  19  1  15
# 48  71  0  15
# 49  75  0  15

# %%
# importing data set using pandas
mba = pd.read_csv("C:/Users/Pravi/Downloads/mba.csv")
mba
# Out:
#      datasrno  workex  gmat
# 0           1      21   720
# 1           2     107   640
# 2           3      57   740
# 3           4      99   690
# 4           5     208   710
# ..        ...     ...   ...
# 768       769      88   620
# 769       770     132   670
# 770       771      28   610
# 771       772      10   610
# 772       773      52   620
#
# [773 rows x 3 columns]

# %%
type(mba)
# Out:
# pandas.core.frame.DataFrame

# %%
mba.head(20)
# Out:
#     datasrno  workex  gmat
# 0          1      21   720
# 1          2     107   640
# 2          3      57   740
# 3          4      99   690
# 4          5     208   710
# 5          6     136   660
# 6          7      70   660
# 7          8     103   710
# 8          9      79   700
# 9         10      22   730
# 10        11      69   700
# 11        12      41   740
# 12        13      72   650
# 13        14      69   720
# 14        15      20   700
# 15        16      21   760
# 16        17      19   710
# 17        18      86   720
# 18        19     231   690
# 19        20      20   770

# %%
mba.loc[[1,2],["gmat"]]
# Out:
#    gmat
# 1   640
# 2   740

# %%
# Finding 3rd and 4rth Business Moments
print(mba.skew())
print(mba.kurt())
# Out:
# datasrno    0.000000
# workex      2.608537
# gmat       -0.595477
# dtype: float64
# datasrno    -1.200000
# workex      13.404732
# gmat         1.167164
# dtype: float64

# %%
mba['gmat'].kurt()
